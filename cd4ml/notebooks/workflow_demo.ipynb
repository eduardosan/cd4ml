# %% [markdown]
# # Introduction
#
# This notebook is a demo on how to setup a basic Workflow to Work with Jupyter Notebooks

# %% [markdown]
# ## Install
#
# First install CD4ML package to the development environment

# %%
# !python ../setup.py develop
# Out:
# Processing /home/eduardo/work
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: cd4ml
#   Building wheel for cd4ml (setup.py) ... done
#   Created wheel for cd4ml: filename=cd4ml-0.0.1-py3-none-any.whl size=6733 sha256=54791abb92a138b2dc00f5a9003cc0547b72b750be3a435d9627b17bda2d95bc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5qpbxoph/wheels/dd/fe/a9/e71b0c4e14d41f4dc4a95af3c2c4d87289e569db2eca1c7602
# Successfully built cd4ml
# Installing collected packages: cd4ml
#   Attempting uninstall: cd4ml
#     Found existing installation: cd4ml 0.0.1
#     Uninstalling cd4ml-0.0.1:
#       Successfully uninstalled cd4ml-0.0.1
# Successfully installed cd4ml-0.0.1

# %% [markdown]
# Install here your project dependencies por the experiment

# %%
# %%writefile requirements.txt
#
# feedparser==6.0.10
# pandas==1.4.2
# openpyxl==3.0.10
# Out:
# Writing requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# Collecting feedparser==6.0.10
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 7.9 MB/s eta 0:00:00
# Collecting pandas==1.4.2
#   Downloading pandas-1.4.2-cp310-cp310-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (11.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 19.5 MB/s eta 0:00:0000:0100:01
# Collecting openpyxl==3.0.10
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 17.4 MB/s eta 0:00:00
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas==1.4.2->-r requirements.txt (line 3)) (2.8.2)
# Collecting numpy>=1.21.0
#   Downloading numpy-1.23.0-cp310-cp310-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (13.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 18.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas==1.4.2->-r requirements.txt (line 3)) (2022.1)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas==1.4.2->-r requirements.txt (line 3)) (1.16.0)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6048 sha256=c12d58707584abf7662e23021ab4792d7ffa7e768f9203393562861d9d562d00
#   Stored in directory: /home/eduardo/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, numpy, feedparser, et-xmlfile, pandas, openpyxl
# Successfully installed et-xmlfile-1.1.0 feedparser-6.0.10 numpy-1.23.0 openpyxl-3.0.10 pandas-1.4.2 sgmllib3k-1.0.0

# %% [markdown]
# ## Data extraction
#
# For this example we will download some news feed data to use as a dataset. As this is an introductory example just a few news will be used

# %% [markdown]
# ### Step 1: download data
#
# The goal is to create the case as a multistep feature extraction. First step is to create a function to download data from a service provider

# %%
feeds_json = {
    "Folha - Brasil - Em Cima da Hora": "https://feeds.folha.uol.com.br/emcimadahora/rss091.xml",
    "G1 - Land Page 1":"https://g1.globo.com/rss/g1/",
    "G1 - Brasil":"https://g1.globo.com/rss/g1/brasil",
}

# %%
import feedparser
import pandas as pd

def fetch_feed_data(feed_rss_url):

    blog_feed = feedparser.parse(feed_rss_url)
        
    posts = blog_feed.entries  
    post_list = []
        
    for post in posts:
        post_dict = dict()
            
        post_dict["TITLE"] = post.title
        post_dict["CONTENT"] = post.summary
        post_dict["LINK"] = post.link
        post_dict["TIME_PUBLISHED"] = post.published
        # post_dict["TAGS"] = [tag.term for tag in post.tags]
            
        post_list.append(post_dict)
    df_post = pd.DataFrame(post_list)
    return df_post

# %% [markdown]
# Now we are going to use this function to define a task using CD4ML

# %%
from cd4ml.task import Task

download = Task(name='download', task=fetch_feed_data)

# %% [markdown]
# Every task in CD4ML has a method name `run` to excute it with args. Let's test it with a feed we know.

# %%
df_g1 = download.run('https://g1.globo.com/rss/g1/')
df_g1
# Out:
#                                                 TITLE  \
# 0   Veja o que abre e o que fecha no feriado do pa...
# 1   Quem é Arilton Moura, pastor preso no Pará pel...
# 2   Planetário de Vitória faz aniversário: confira...
# 3   Laboratório para caracterização e gestão de re...
# 4   Homem se apresenta à polícia de SP dizendo que...
# 5   Em noite de muitos recados em defesa da democr...
# 6   Natal sanciona isenção de ISS para permissioná...
# 7           PRF apreende 8 kg de prata em Atibaia, SP
# 8   Beneficiários do Auxílio Brasil já podem solic...
# 9   Norte Fluminense vai receber unidade piloto do...
# 10  Apesar da tecnologia dos smartphones, relógios...
# 11  PF cumpre mandados em operação de combate a or...
# 12  Chuvas são registradas em municípios da Mata S...
# 13  A arquitetura e natureza se encontram no Arbo ...
# 14  Preso em ação que apura desvios no MEC, ex-ass...
# 15  Perda de empregos entre mulheres foi mais inte...
# 16  Corpo é encontrado carbonizado em Caratinga ap...
# 17  Juiz que determinou prisão de Milton Ribeiro s...
# 18                                  COFER Ferro e Aço
# 19  Preso pela PF, Milton Ribeiro foi 'mau ministr...
# 20  'A gente marcou a história deles e eles a noss...
# 21  Morre idoso que foi baleado durante assalto no...
# 22  Sábado é o Dia D de vacinação contra influenza...
# 23  Ataque em Itajubá: estudante ferido durante aç...
# 24  Instituto de Música promove concerto com obras...
# 25  Mauro Paulino estreia nesta quinta como coment...
# 26  Prefeitura de Maceió antecipa feriado de Flori...
# 27  Polícia Militar prende homem por receptação e ...
# 28  Anel Viário Sul: caminhonete com motorista emb...
# 29  Dupla é condenada por homicídio qualificado de...
# 30  Terra Brasilis apresenta o último episódio nes...
# 31  Cuiabano de 'tchapa e cruz' comemora 103 anos ...
# 32  Vídeo: procurador que espancou a chefe é preso...
# 33  A 100 dias da eleição, Fachin diz que Justiça ...
# 34  Laboratório da Ufopa seleciona voluntários par...
# 35  Instagram apresenta instabilidade nesta quinta...
# 36  SineBahia divulga vagas de emprego e estágio e...
# 37  Operação policial apreende veículo com suspeit...
# 38  Barbixas apresenta espetáculo de humor 'Improv...
# 39  Orquestra de Violeiros de Araras resgata histó...
#
#                                               CONTENT  \
# 0   <img src="https://s2.glbimg.com/X6nwl6tG1i3uDU...
# 1   <img src="https://s2.glbimg.com/KdvTp7vLIQgHSo...
# 2   <img src="https://s2.glbimg.com/kHRaUCHBGBd1za...
# 3   <img src="https://s2.glbimg.com/l_WpqgAvdsn36v...
# 4   <img src="https://s2.glbimg.com/7LOZFzJyVUY8SW...
# 5   A noite de quarta-feira (22) em Brasília foi d...
# 6   <img src="https://s2.glbimg.com/Gz16XivaBWjQle...
# 7   <img src="https://s2.glbimg.com/giVTZRnJ71fZ__...
# 8   <img src="https://s2.glbimg.com/0YiFmeEfDLDLdU...
# 9   <img src="https://s2.glbimg.com/0QpFBdvf3KPq0E...
# 10  <img src="https://s2.glbimg.com/C2qWMecTK2M1hY...
# 11  <img src="https://s2.glbimg.com/n_den8nfT_74-L...
# 12  <img src="https://s2.glbimg.com/kylkQc1UIPPb-0...
# 13  <img src="https://s2.glbimg.com/mqTCEyQ1ZESbhy...
# 14  <img src="https://s2.glbimg.com/-9E8zKLtVxB58_...
# 15  “A participação das mulheres entre os assalari...
# 16  Vítima não identificada estava nos fundos de u...
# 17  Segundo assessoria do tribunal, Renato Borelli...
# 18  <img src="https://s2.glbimg.com/e79el01y_SDJrK...
# 19  Pré-candidato do PT disse que prisão depende d...
# 20  <img src="https://s2.glbimg.com/RW09bjxZxuOlc6...
# 21  <img src="https://s2.glbimg.com/627cn5xI31YoCf...
# 35  https://g1.globo.com/tecnologia/noticia/2022/0...
# 36  https://g1.globo.com/ba/bahia/blogdoemprego/no...
# 37  https://g1.globo.com/sp/presidente-prudente-re...
# 38  https://g1.globo.com/sp/sao-carlos-regiao/noti...
# 39  https://g1.globo.com/sp/piracicaba-regiao/noti...
#
#                      TIME_PUBLISHED
# 0   Thu, 23 Jun 2022 14:16:28 -0000
# 1   Thu, 23 Jun 2022 14:16:28 -0000
# 2   Thu, 23 Jun 2022 14:15:48 -0000
# 3   Thu, 23 Jun 2022 14:15:45 -0000
# 4   Thu, 23 Jun 2022 14:15:42 -0000
# 5   Thu, 23 Jun 2022 14:14:05 -0000
# 6   Thu, 23 Jun 2022 14:13:58 -0000
# 7   Thu, 23 Jun 2022 14:12:49 -0000
# 8   Thu, 23 Jun 2022 14:12:38 -0000
# 9   Thu, 23 Jun 2022 14:12:11 -0000
# 10  Thu, 23 Jun 2022 14:10:05 -0000
# 11  Thu, 23 Jun 2022 14:10:03 -0000
# 12  Thu, 23 Jun 2022 14:09:53 -0000
# 13  Thu, 23 Jun 2022 14:09:00 -0000
# 14  Thu, 23 Jun 2022 14:08:34 -0000
# 15  Thu, 23 Jun 2022 14:08:06 -0000
# 16  Thu, 23 Jun 2022 14:07:43 -0000
# 17  Thu, 23 Jun 2022 14:07:15 -0000
# 18  Thu, 23 Jun 2022 14:06:54 -0000
# 19  Thu, 23 Jun 2022 14:05:26 -0000
# 20  Thu, 23 Jun 2022 14:04:28 -0000
# 21  Thu, 23 Jun 2022 14:04:14 -0000
# 22  Thu, 23 Jun 2022 14:03:30 -0000
# 23  Thu, 23 Jun 2022 14:02:52 -0000
# 24  Thu, 23 Jun 2022 14:00:56 -0000
# 25  Thu, 23 Jun 2022 13:59:57 -0000
# 26  Thu, 23 Jun 2022 13:58:56 -0000
# 27  Thu, 23 Jun 2022 13:58:30 -0000
# 28  Thu, 23 Jun 2022 13:56:58 -0000
# 29  Thu, 23 Jun 2022 13:56:23 -0000
# 30  Thu, 23 Jun 2022 13:56:20 -0000
# 31  Thu, 23 Jun 2022 13:54:52 -0000
# 32  Thu, 23 Jun 2022 13:54:09 -0000
# 33  Thu, 23 Jun 2022 13:52:52 -0000
# 34  Thu, 23 Jun 2022 13:50:41 -0000
# 35  Thu, 23 Jun 2022 13:50:17 -0000
# 36  Thu, 23 Jun 2022 13:47:58 -0000
# 37  Thu, 23 Jun 2022 13:47:56 -0000
# 38  Thu, 23 Jun 2022 13:47:26 -0000
# 39  Thu, 23 Jun 2022 13:45:03 -0000

# %% [markdown]
# ### Step 2: create your first workflow
#
# Now that we downloaded the data we can use to create new features. Let's create a workflow to download feeds from differente providers

# %%
from cd4ml.task import Task
from cd4ml.workflow import Workflow

download_g1 = Task(name='download_g1', task=fetch_feed_data)
download_g1_brasil = Task(name='download_g1_brasil', task=fetch_feed_data)
download_folha = Task(name='download_folha', task=fetch_feed_data)

feeds_json = {
    "download_folha": "https://feeds.folha.uol.com.br/emcimadahora/rss091.xml",
    "download_g1":"https://g1.globo.com/rss/g1/",
    "download_g1_brasil":"https://g1.globo.com/rss/g1/brasil",
}

w = Workflow()
w.add_task(download_g1)
w.add_task(download_g1_brasil)
w.add_task(download_folha)
output = w.run(params=feeds_json, executor='local')
